# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer
checkpoint = "gpt2"

# %%
bpe_tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
"""
Step by step
"""
tokens = bpe_tokenizer.tokenize("This is some text to be tokenized")

ids = bpe_tokenizer.convert_tokens_to_ids(tokens)

final_input = bpe_tokenizer.prepare_for_model(ids)
# Out:
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
print(final_input)
# Out:
# {'input_ids': [1212, 318, 617, 2420, 284, 307, 11241, 1143], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}

# %%
"""
Using call method
"""
input_tokens = bpe_tokenizer("This is some text to be tokenized")
print(input_tokens)
# Out:
# {'input_ids': [1212, 318, 617, 2420, 284, 307, 11241, 1143], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}

# %% [markdown]
# ##Code from scatch

# %%
from transformers import GPT2Tokenizer, TFGPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = TFGPT2Model.from_pretrained('gpt2')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='tf')
output = model(encoded_input)

# %%
#or from transformers import GPT2Tokenizer, TFGPT2Model
#https://huggingface.co/gpt2
from transformers import AutoModelForCausalLM

#Example for passing pre-processing tokens into model
model = AutoModelForCausalLM.from_pretrained('gpt2')
